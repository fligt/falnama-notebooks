# %%
import base64
import io, requests
from IPython.display import Image, display
from PIL import Image as im
import matplotlib.pyplot as plt

def mm(title, graph):
    graphbytes = graph.encode("utf8")
    base64_bytes = base64.urlsafe_b64encode(graphbytes)
    base64_string = base64_bytes.decode("ascii")

    img = im.open(io.BytesIO(requests.get('https://mermaid.ink/img/' + base64_string).content))
    
    h, w = img.size
    w_plot = 12
    h_plot = int(w_plot * (h / w))
    fig, ax = plt.subplots(figsize=[w_plot, h_plot])
    ax.imshow(img)
    ax.set_title(title)
    ax.axis('off')

# %%
img = mm('fairdatanow', """
kanban
    Todo
        [Test webdav upload/edit]
        [Create working example of query with visualiztion]
        [change root cache folder to .cache/fairdatanow]
        
        
    Doing
        [Making kanbanboard]@{assigned: 'Koen', priority: 'High'}
        
    Done
""")

# %%
mm('maxrf4u', """
kanban
    Todo 
        [Replace pooch with fairdatanow based on query] 
        [Documentation based on Falnama data instead of Suzanna]
        
    Doing 

    Done
""")

# %%
PIL.Image.
