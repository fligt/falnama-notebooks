# %% [markdown]
# # fsspec trials

# %% [markdown]
# *Would like to know if `fsspec` can be used to download only parts of our datastack zipstore files.*

# %% [markdown]
# %pip install fsspec

# %% [markdown]
# ## Installation and cloud zip example
#
# https://filesystem-spec.readthedocs.io/en/latest/index.html

# %%
from fsspec.implementations.zip.
