# %% [markdown]
# # This has been a roller coaster

# %% [markdown]
# Looking back on our Falnama project coding adventure what did we set out to do? Which problems did we encounter? How did we solve them? And how to move forward?
