# %% [markdown]
# # Backblaze urls voor Koen

# %%
from glob import glob
import os

# %%
os.chdir('../../../data/interim/maxrf/datastacks/')

# %%
datastack_files = glob('*.datastack')
datastack_files
# Out:
# ['WM-71803-01_400_600_50.datastack',
#  'WM-71803-03_250_300_50.datastack',
#  'WM-71803-08_250_300_50.datastack',
#  'WM-71803-10_250_300_50.datastack',
#  'WM-71803-12_250_300_50.datastack',
#  'WM-71803-13_400_600_50.datastack',
#  'WM-71803-17_400_600_50.datastack',
#  'WM-71803-18_400_300_50_det.datastack',
#  'WM-71803-18_400_500_50.datastack',
#  'WM-71803-19_400_600_50.datastack',
#  'WM-71803-23_400_600_50.datastack',
#  'WM-71803-24_400_600_50.datastack',
#  'WM-71803-29_400_500_50.datastack',
#  'WM-71803-30_250_300_50.datastack',
#  'WM-71803-31_400_600_50.datastack',
#  'WM-71803-35_400_500_50.datastack']

# %%
urls = ['https://f002.backblazeb2.com/file/falnama-data/datastacks/' + f for f in datastack_files]
urls
# Out:
# ['https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-01_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-03_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-08_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-10_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-12_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-13_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-17_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-18_400_300_50_det.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-18_400_500_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-19_400_600_50.datastack',
# ...

# %% [markdown]
# # Backblaze urls voor Koen

# %%
from glob import glob
import os

# %%
os.chdir('../../../data/interim/maxrf/datastacks/')

# %%
datastack_files = glob('*.datastack')
datastack_files
# Out:
# ['WM-71803-01_400_600_50.datastack',
#  'WM-71803-03_250_300_50.datastack',
#  'WM-71803-08_250_300_50.datastack',
#  'WM-71803-10_250_300_50.datastack',
#  'WM-71803-12_250_300_50.datastack',
#  'WM-71803-13_400_600_50.datastack',
#  'WM-71803-17_400_600_50.datastack',
#  'WM-71803-18_400_300_50_det.datastack',
#  'WM-71803-18_400_500_50.datastack',
#  'WM-71803-19_400_600_50.datastack',
#  'WM-71803-23_400_600_50.datastack',
#  'WM-71803-24_400_600_50.datastack',
#  'WM-71803-29_400_500_50.datastack',
#  'WM-71803-30_250_300_50.datastack',
#  'WM-71803-31_400_600_50.datastack',
#  'WM-71803-35_400_500_50.datastack']

# %%
urls = ['https://f002.backblazeb2.com/file/falnama-data/datastacks/' + f for f in datastack_files]
urls
# Out:
# ['https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-01_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-03_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-08_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-10_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-12_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-13_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-17_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-18_400_300_50_det.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-18_400_500_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-19_400_600_50.datastack',
# ...

# %% [markdown]
# # Backblaze urls voor Koen

# %%
from glob import glob
import os

# %%
os.chdir('../../../data/interim/maxrf/datastacks/')

# %%
datastack_files = glob('*.datastack')
datastack_files
# Out:
# ['WM-71803-01_400_600_50.datastack',
#  'WM-71803-03_250_300_50.datastack',
#  'WM-71803-08_250_300_50.datastack',
#  'WM-71803-10_250_300_50.datastack',
#  'WM-71803-12_250_300_50.datastack',
#  'WM-71803-13_400_600_50.datastack',
#  'WM-71803-17_400_600_50.datastack',
#  'WM-71803-18_400_300_50_det.datastack',
#  'WM-71803-18_400_500_50.datastack',
#  'WM-71803-19_400_600_50.datastack',
#  'WM-71803-23_400_600_50.datastack',
#  'WM-71803-24_400_600_50.datastack',
#  'WM-71803-29_400_500_50.datastack',
#  'WM-71803-30_250_300_50.datastack',
#  'WM-71803-31_400_600_50.datastack',
#  'WM-71803-35_400_500_50.datastack']

# %%
urls = ['https://f002.backblazeb2.com/file/falnama-data/datastacks/' + f for f in datastack_files]
urls
# Out:
# ['https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-01_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-03_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-08_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-10_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-12_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-13_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-17_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-18_400_300_50_det.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-18_400_500_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-19_400_600_50.datastack',
# ...

# %% [markdown]
# # Backblaze urls voor Koen

# %%
from glob import glob
import os

# %%
os.chdir('../../../data/interim/maxrf/datastacks/')

# %%
datastack_files = glob('*.datastack')
datastack_files
# Out:
# ['WM-71803-01_400_600_50.datastack',
#  'WM-71803-03_250_300_50.datastack',
#  'WM-71803-08_250_300_50.datastack',
#  'WM-71803-10_250_300_50.datastack',
#  'WM-71803-12_250_300_50.datastack',
#  'WM-71803-13_400_600_50.datastack',
#  'WM-71803-17_400_600_50.datastack',
#  'WM-71803-18_400_300_50_det.datastack',
#  'WM-71803-18_400_500_50.datastack',
#  'WM-71803-19_400_600_50.datastack',
#  'WM-71803-23_400_600_50.datastack',
#  'WM-71803-24_400_600_50.datastack',
#  'WM-71803-29_400_500_50.datastack',
#  'WM-71803-30_250_300_50.datastack',
#  'WM-71803-31_400_600_50.datastack',
#  'WM-71803-35_400_500_50.datastack']

# %%
urls = ['https://f002.backblazeb2.com/file/falnama-data/datastacks/' + f for f in datastack_files]
urls
# Out:
# ['https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-01_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-03_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-08_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-10_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-12_250_300_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-13_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-17_400_600_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-18_400_300_50_det.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-18_400_500_50.datastack',
#  'https://f002.backblazeb2.com/file/falnama-data/datastacks/WM-71803-19_400_600_50.datastack',
# ...
