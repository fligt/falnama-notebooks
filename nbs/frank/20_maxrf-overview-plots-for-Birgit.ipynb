# %% [markdown]
# # MA-XRF overview plots for Birgit

# %%
import maxrf4u as mx 
import matplotlib.pyplot as plt
from glob import glob 
import re 
import os

# %%
os.chdir('../../../data/interim')

# %%
ls
# Out:
# '02. JPEG Res.zip'*        maxrf/                 worldmap/
#  3.xray-jpgs.zip*          maxrf-overviews/       xray-jpgs/
#  Weimar-PhaseOne-rot270/   rgb_jpegs-from-tifs/   xray-jpgs-stitched/
