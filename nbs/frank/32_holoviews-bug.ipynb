# %% [markdown]
# # Holoviews bug

# %% [markdown]
# > How to fix disappearing elements??

# %% [markdown]
# Here is a minimal example that shows the problem.

# %%
import holoviews as hv 
from holoviews import opts
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3492ca6a-0f77-4b9f-a533-40d97739e81f'>
#   <div id="af2c3fb1-439c-4026-a2de-6dd4e587f83f" data-root-id="3492ca6a-0f77-4b9f-a533-40d97739e81f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# I create two simple `Curves` and combine them in an overlay. The first time I run this cell it works fine. But simply rerunning can make the curves disappear in one plot or both...

# %%
c1 = hv.Curve(([2, 4], [1, 1]), 'X', 'Y', group='A', label='01')
c2 = hv.Curve(([3, 5], [2, 2]), 'XX', 'YY', group='B', label='02').opts(color='red')

c3 = c1 + c2

# %%
c3
# Out:
# :Layout
#    .A.A_01 :Curve   [X]   (Y)
#    .B.A_02 :Curve   [XX]   (YY)

# %%
c3
# Out:
# :Layout
#    .A.A_01 :Curve   [X]   (Y)
#    .B.A_02 :Curve   [XX]   (YY)

# %% [markdown]
# If I reload the browser the curves typically reappear.
