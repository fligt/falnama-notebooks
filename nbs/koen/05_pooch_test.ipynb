# %%
import falnama_data
import maxrf4u as mx

# %%
falnama_data.download_all()
# Out:
# ...
# 100%|█████████████████████████████████████| 1.95G/1.95G [00:00<00:00, 1.67TB/s]
# Checked 1/16 files
# Checked 2/16 files
# Checked 3/16 files
# Checked 4/16 files
# Checked 5/16 files
# Checked 6/16 files
# Checked 7/16 files
# Checked 8/16 files
# Checked 9/16 files
# Checked 10/16 files
# Checked 11/16 files
# Checked 12/16 files
# Checked 13/16 files
# Checked 14/16 files
# Checked 15/16 files
# Checked 16/16 files
# All data is up to date!

# %%
datastack_files = falnama_data.get_datastack_files()
datastack_files
# Out:
# ['/home/koen-van-tilburg/snap/jupyterlab-desktop/common/.cache/falnama-notebooks/WM-71803-01_400_600_50.datastack',
#  '/home/koen-van-tilburg/snap/jupyterlab-desktop/common/.cache/falnama-notebooks/WM-71803-03_250_300_50.datastack',
#  '/home/koen-van-tilburg/snap/jupyterlab-desktop/common/.cache/falnama-notebooks/WM-71803-08_250_300_50.datastack',
#  '/home/koen-van-tilburg/snap/jupyterlab-desktop/common/.cache/falnama-notebooks/WM-71803-10_250_300_50.datastack',
#  '/home/koen-van-tilburg/snap/jupyterlab-desktop/common/.cache/falnama-notebooks/WM-71803-12_250_300_50.datastack',
#  '/home/koen-van-tilburg/snap/jupyterlab-desktop/common/.cache/falnama-notebooks/WM-71803-13_400_600_50.datastack',
#  '/home/koen-van-tilburg/snap/jupyterlab-desktop/common/.cache/falnama-notebooks/WM-71803-17_400_600_50.datastack',
#  '/home/koen-van-tilburg/snap/jupyterlab-desktop/common/.cache/falnama-notebooks/WM-71803-18_400_300_50_det.datastack',
# ...
