# %%
import falnama_data
import maxrf4u as mx

# %%
downloader = falnama_data.Downloader()

# %%
datastack_files = downloader.download_all()
datastack_files
# Out:
# Checked 1/16 files
# Checked 2/16 files
# Checked 3/16 files
# Checked 4/16 files
# Checked 5/16 files
# Checked 6/16 files
# Checked 7/16 files
# Checked 8/16 files
# Checked 9/16 files
# Checked 10/16 files
# Checked 11/16 files
# Checked 12/16 files
# Checked 13/16 files
# Checked 14/16 files
# Checked 15/16 files
# Checked 16/16 files
# All data is up to date!
